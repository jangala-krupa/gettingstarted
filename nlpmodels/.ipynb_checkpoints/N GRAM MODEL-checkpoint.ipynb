# %%
import random
import nltk

# %%
text = """Cricket is a bat-and-ball game played between two teams of eleven players on a field at the centre of which is a 20-metre (22-yard) pitch with a wicket at each end, each comprising two bails balanced on three stumps. The batting side scores runs by striking the ball bowled at the wicket with the bat, while the bowling and fielding side tries to prevent this and dismiss each player (so they are "out"). Means of dismissal include being bowled, when the ball hits the stumps and dislodges the bails, and by the fielding side catching the ball after it is hit by the bat, but before it hits the ground. When ten players have been dismissed, the innings ends and the teams swap roles. The game is adjudicated by two umpires, aided by a third umpire and match referee in international matches. They communicate with two off-field scorers who record the match's statistical information.

There are various formats ranging from Twenty20, played over a few hours with each team batting for a single innings of 20 overs, to Test matches, played over five days with unlimited overs and the teams each batting for two innings of unlimited length. Traditionally cricketers play in all-white kit, but in limited overs cricket they wear club or team colours. In addition to the basic kit, some players wear protective gear to prevent injury caused by the ball, which is a hard, solid spheroid made of compressed leather with a slightly raised sewn seam enclosing a cork core which is layered with tightly wound string.


Historically, cricket's origins are uncertain and the earliest definite reference is in south-east England in the middle of the 16th century. It spread globally with the expansion of the British Empire, leading to the first international matches in the second half of the 19th century. The game's governing body is the International Cricket Council (ICC), which has over 100 members, twelve of which are full members who play Test matches. The game's rules are held in a code called the Laws of Cricket which is owned and maintained by Marylebone Cricket Club (MCC) in London. The sport is followed primarily in the Indian subcontinent, Australasia, the United Kingdom, Ireland, southern Africa and the West Indies, its globalisation occurring during the expansion of the British Empire and remaining popular into the 21st century.[1] Women's cricket, which is organised and played separately, has also achieved international standard. The most successful side playing international cricket is Australia, having won seven One Day International trophies, including five World Cups, more than any other country, and having been the top-rated Test side more than any other country."""

# %%
n= 10

# %%
ngrams={}

# %%
for i in range(len(text)-n):
    gram = text[i:i+n]
    if gram not in ngrams.keys():
        ngrams[gram]=[]
    ngrams[gram].append(text[i+n])

# %%
ngrams
# Out:
# {'Cricket is a': ['bat-and-ball'],
#  'is a bat-and-ball': ['game'],
#  'a bat-and-ball game': ['played'],
#  'bat-and-ball game played': ['between'],
#  'game played between': ['two'],
#  'played between two': ['teams'],
#  'between two teams': ['of'],
#  'two teams of': ['eleven'],
#  'teams of eleven': ['players'],
#  'of eleven players': ['on'],
#  'eleven players on': ['a'],
#  'players on a': ['field'],
#  'on a field': ['at'],
#  'a field at': ['the'],
#  'field at the': ['centre'],
#  'at the centre': ['of'],
#  'the centre of': ['which'],
#  'centre of which': ['is'],
#  'of which is': ['a'],
#  'which is a': ['20-metre', 'hard'],
#  'is a 20-metre': ['('],
#  'a 20-metre (': ['22-yard'],
#  '20-metre ( 22-yard': [')'],
#  '( 22-yard )': ['pitch'],
#  '22-yard ) pitch': ['with'],
#  ') pitch with': ['a'],
#  'pitch with a': ['wicket'],
#  'with a wicket': ['at'],
#  'a wicket at': ['each'],
#  'wicket at each': ['end'],
#  'at each end': [','],
#  'each end ,': ['each'],
#  'end , each': ['comprising'],
#  ', each comprising': ['two'],
#  'each comprising two': ['bails'],
#  'comprising two bails': ['balanced'],
#  'two bails balanced': ['on'],
#  'bails balanced on': ['three'],
#  'balanced on three': ['stumps'],
#  'on three stumps': ['.'],
#  'three stumps .': ['The'],
#  'stumps . The': ['batting'],
#  '. The batting': ['side'],
#  'The batting side': ['scores'],
#  'batting side scores': ['runs'],
#  'side scores runs': ['by'],
#  'scores runs by': ['striking'],
#  'runs by striking': ['the'],
#  'by striking the': ['ball'],
#  'striking the ball': ['bowled'],
#  'the ball bowled': ['at'],
#  'ball bowled at': ['the'],
#  'bowled at the': ['wicket'],
#  'at the wicket': ['with'],
#  'the wicket with': ['the'],
#  'wicket with the': ['bat'],
#  'with the bat': [','],
#  'the bat ,': ['while', 'but'],
#  'bat , while': ['the'],
#  ', while the': ['bowling'],
#  'while the bowling': ['and'],
#  'the bowling and': ['fielding'],
#  'bowling and fielding': ['side'],
#  'and fielding side': ['tries'],
#  'fielding side tries': ['to'],
#  'side tries to': ['prevent'],
#  'tries to prevent': ['this'],
#  'to prevent this': ['and'],
#  'prevent this and': ['dismiss'],
#  'this and dismiss': ['each'],
#  'and dismiss each': ['player'],
#  'dismiss each player': ['('],
#  'each player (': ['so'],
#  'player ( so': ['they'],
#  '( so they': ['are'],
#  'so they are': ['``'],
#  'they are ``': ['out'],
#  'are `` out': ["''"],
#  "`` out ''": [')'],
#  "out '' )": ['.'],
#  "'' ) .": ['Means'],
#  ') . Means': ['of'],
#  '. Means of': ['dismissal'],
#  'Means of dismissal': ['include'],
#  'of dismissal include': ['being'],
#  'dismissal include being': ['bowled'],
#  'include being bowled': [','],
#  'being bowled ,': ['when'],
#  'bowled , when': ['the'],
#  ', when the': ['ball'],
#  'when the ball': ['hits'],
#  'the ball hits': ['the'],
#  'ball hits the': ['stumps'],
#  'hits the stumps': ['and'],
#  'the stumps and': ['dislodges'],
#  'stumps and dislodges': ['the'],
#  'and dislodges the': ['bails'],
#  'dislodges the bails': [','],
#  'the bails ,': ['and'],
#  'bails , and': ['by'],
#  ', and by': ['the'],
#  'and by the': ['fielding'],
#  'by the fielding': ['side'],
#  'the fielding side': ['catching'],
#  'fielding side catching': ['the'],
#  'side catching the': ['ball'],
#  'catching the ball': ['after'],
#  'the ball after': ['it'],
#  'ball after it': ['is'],
#  'after it is': ['hit'],
#  'it is hit': ['by'],
#  'is hit by': ['the'],
#  'hit by the': ['bat'],
#  'by the bat': [','],
#  'bat , but': ['before'],
#  ', but before': ['it'],
#  'but before it': ['hits'],
#  'before it hits': ['the'],
#  'it hits the': ['ground'],
#  'hits the ground': ['.'],
#  'the ground .': ['When'],
#  'ground . When': ['ten'],
#  '. When ten': ['players'],
#  'When ten players': ['have'],
#  'ten players have': ['been'],
#  'players have been': ['dismissed'],
#  'have been dismissed': [','],
#  'been dismissed ,': ['the'],
#  'dismissed , the': ['innings'],
#  ', the innings': ['ends'],
#  'the innings ends': ['and'],
#  'innings ends and': ['the'],
#  'ends and the': ['teams'],
#  'and the teams': ['swap', 'each'],
#  'the teams swap': ['roles'],
#  'teams swap roles': ['.'],
#  'swap roles .': ['The'],
#  'roles . The': ['game'],
#  '. The game': ['is', "'s", "'s"],
#  'The game is': ['adjudicated'],
#  'game is adjudicated': ['by'],
#  'is adjudicated by': ['two'],
#  'adjudicated by two': ['umpires'],
#  'by two umpires': [','],
#  'two umpires ,': ['aided'],
#  'umpires , aided': ['by'],
#  ', aided by': ['a'],
#  'aided by a': ['third'],
#  'by a third': ['umpire'],
#  'a third umpire': ['and'],
#  'third umpire and': ['match'],
#  'umpire and match': ['referee'],
#  'and match referee': ['in'],
#  'match referee in': ['international'],
#  'referee in international': ['matches'],
#  'in international matches': ['.'],
#  'international matches .': ['They'],
#  'matches . They': ['communicate'],
#  '. They communicate': ['with'],
#  'They communicate with': ['two'],
#  'communicate with two': ['off-field'],
#  'with two off-field': ['scorers'],
#  'two off-field scorers': ['who'],
#  'off-field scorers who': ['record'],
#  'scorers who record': ['the'],
#  'who record the': ['match'],
#  'record the match': ["'s"],
#  "the match 's": ['statistical'],
#  "match 's statistical": ['information'],
#  "'s statistical information": ['.'],
#  'statistical information .': ['There'],
#  'information . There': ['are'],
#  '. There are': ['various'],
#  'There are various': ['formats'],
#  'are various formats': ['ranging'],
#  'various formats ranging': ['from'],
#  'formats ranging from': ['Twenty20'],
#  'ranging from Twenty20': [','],
#  'from Twenty20 ,': ['played'],
#  'Twenty20 , played': ['over'],
#  ', played over': ['a', 'five'],
#  'played over a': ['few'],
#  'over a few': ['hours'],
#  'a few hours': ['with'],
#  'few hours with': ['each'],
#  'hours with each': ['team'],
#  'with each team': ['batting'],
#  'each team batting': ['for'],
#  'team batting for': ['a'],
#  'batting for a': ['single'],
#  'for a single': ['innings'],
#  'a single innings': ['of'],
#  'single innings of': ['20'],
#  'innings of 20': ['overs'],
#  'of 20 overs': [','],
#  '20 overs ,': ['to'],
#  'overs , to': ['Test'],
#  ', to Test': ['matches'],
#  'to Test matches': [','],
#  'Test matches ,': ['played'],
#  'matches , played': ['over'],
#  'played over five': ['days'],
#  'over five days': ['with'],
#  'five days with': ['unlimited'],
#  'days with unlimited': ['overs'],
#  'with unlimited overs': ['and'],
#  'unlimited overs and': ['the'],
#  'overs and the': ['teams'],
#  'the teams each': ['batting'],
#  'teams each batting': ['for'],
#  'each batting for': ['two'],
#  'batting for two': ['innings'],
#  'for two innings': ['of'],
#  'two innings of': ['unlimited'],
#  'innings of unlimited': ['length'],
#  'of unlimited length': ['.'],
#  'unlimited length .': ['Traditionally'],
#  'length . Traditionally': ['cricketers'],
#  '. Traditionally cricketers': ['play'],
#  'Traditionally cricketers play': ['in'],
#  'cricketers play in': ['all-white'],
#  'play in all-white': ['kit'],
#  'in all-white kit': [','],
#  'all-white kit ,': ['but'],
#  'kit , but': ['in'],
#  ', but in': ['limited'],
#  'but in limited': ['overs'],
#  'in limited overs': ['cricket'],
#  'limited overs cricket': ['they'],
#  'overs cricket they': ['wear'],
#  'cricket they wear': ['club'],
#  'they wear club': ['or'],
#  'wear club or': ['team'],
#  'club or team': ['colours'],
#  'or team colours': ['.'],
#  'team colours .': ['In'],
#  'colours . In': ['addition'],
#  '. In addition': ['to'],
#  'In addition to': ['the'],
#  'addition to the': ['basic'],
#  'to the basic': ['kit'],
#  'the basic kit': [','],
#  'basic kit ,': ['some'],
#  'kit , some': ['players'],
#  ', some players': ['wear'],
#  'some players wear': ['protective'],
#  'players wear protective': ['gear'],
#  'wear protective gear': ['to'],
#  'protective gear to': ['prevent'],
#  'gear to prevent': ['injury'],
#  'to prevent injury': ['caused'],
#  'prevent injury caused': ['by'],
#  'injury caused by': ['the'],
#  'caused by the': ['ball'],
#  'by the ball': [','],
#  'the ball ,': ['which'],
#  'ball , which': ['is'],
#  ', which is': ['a', 'organised'],
#  'is a hard': [','],
#  'a hard ,': ['solid'],
#  'hard , solid': ['spheroid'],
#  ', solid spheroid': ['made'],
#  'solid spheroid made': ['of'],
#  'spheroid made of': ['compressed'],
#  'made of compressed': ['leather'],
#  'of compressed leather': ['with'],
#  'compressed leather with': ['a'],
#  'leather with a': ['slightly'],
#  'with a slightly': ['raised'],
#  'a slightly raised': ['sewn'],
#  'slightly raised sewn': ['seam'],
#  'raised sewn seam': ['enclosing'],
#  'sewn seam enclosing': ['a'],
#  'seam enclosing a': ['cork'],
#  'enclosing a cork': ['core'],
#  'a cork core': ['which'],
#  'cork core which': ['is'],
#  'core which is': ['layered'],
#  'which is layered': ['with'],
#  'is layered with': ['tightly'],
#  'layered with tightly': ['wound'],
#  'with tightly wound': ['string'],
#  'tightly wound string': ['.'],
#  'wound string .': ['Historically'],
#  'string . Historically': [','],
#  '. Historically ,': ['cricket'],
#  'Historically , cricket': ["'s"],
#  ", cricket 's": ['origins'],
#  "cricket 's origins": ['are'],
#  "'s origins are": ['uncertain'],
#  'origins are uncertain': ['and'],
#  'are uncertain and': ['the'],
#  'uncertain and the': ['earliest'],
#  'and the earliest': ['definite'],
#  'the earliest definite': ['reference'],
#  'earliest definite reference': ['is'],
#  'definite reference is': ['in'],
#  'reference is in': ['south-east'],
#  'is in south-east': ['England'],
#  'in south-east England': ['in'],
#  'south-east England in': ['the'],
#  'England in the': ['middle'],
#  'in the middle': ['of'],
#  'the middle of': ['the'],
#  'middle of the': ['16th'],
#  'of the 16th': ['century'],
#  'the 16th century': ['.'],
#  '16th century .': ['It'],
#  'century . It': ['spread'],
#  '. It spread': ['globally'],
#  'It spread globally': ['with'],
#  'spread globally with': ['the'],
#  'globally with the': ['expansion'],
#  'with the expansion': ['of'],
#  'the expansion of': ['the', 'the'],
#  'expansion of the': ['British', 'British'],
#  'of the British': ['Empire', 'Empire'],
#  'the British Empire': [',', 'and'],
#  'British Empire ,': ['leading'],
#  'Empire , leading': ['to'],
#  ', leading to': ['the'],
#  'leading to the': ['first'],
#  'to the first': ['international'],
#  'the first international': ['matches'],
#  'first international matches': ['in'],
#  'international matches in': ['the'],
#  'matches in the': ['second'],
#  'in the second': ['half'],
#  'the second half': ['of'],
#  'second half of': ['the'],
#  'half of the': ['19th'],
#  'of the 19th': ['century'],
#  'the 19th century': ['.'],
#  '19th century .': ['The'],
#  'century . The': ['game'],
#  "The game 's": ['governing', 'rules'],
#  "game 's governing": ['body'],
#  "'s governing body": ['is'],
#  'governing body is': ['the'],
#  'body is the': ['International'],
#  'is the International': ['Cricket'],
#  'the International Cricket': ['Council'],
#  'International Cricket Council': ['('],
#  'Cricket Council (': ['ICC'],
#  'Council ( ICC': [')'],
#  '( ICC )': [','],
#  'ICC ) ,': ['which'],
#  ') , which': ['has'],
#  ', which has': ['over'],
#  'which has over': ['100'],
#  'has over 100': ['members'],
#  'over 100 members': [','],
#  '100 members ,': ['twelve'],
#  'members , twelve': ['of'],
#  ', twelve of': ['which'],
#  'twelve of which': ['are'],
#  'of which are': ['full'],
#  'which are full': ['members'],
#  'are full members': ['who'],
#  'full members who': ['play'],
#  'members who play': ['Test'],
#  'who play Test': ['matches'],
#  'play Test matches': ['.'],
#  'Test matches .': ['The'],
#  'matches . The': ['game'],
#  "game 's rules": ['are'],
#  "'s rules are": ['held'],
#  'rules are held': ['in'],
#  'are held in': ['a'],
#  'held in a': ['code'],
#  'in a code': ['called'],
#  'a code called': ['the'],
#  'code called the': ['Laws'],
#  'called the Laws': ['of'],
#  'the Laws of': ['Cricket'],
#  'Laws of Cricket': ['which'],
#  'of Cricket which': ['is'],
#  'Cricket which is': ['owned'],
#  'which is owned': ['and'],
#  'is owned and': ['maintained'],
#  'owned and maintained': ['by'],
#  'and maintained by': ['Marylebone'],
#  'maintained by Marylebone': ['Cricket'],
#  'by Marylebone Cricket': ['Club'],
#  'Marylebone Cricket Club': ['('],
#  'Cricket Club (': ['MCC'],
#  'Club ( MCC': [')'],
#  '( MCC )': ['in'],
#  'MCC ) in': ['London'],
#  ') in London': ['.'],
#  'in London .': ['The'],
#  'London . The': ['sport'],
#  '. The sport': ['is'],
#  'The sport is': ['followed'],
#  'sport is followed': ['primarily'],
#  'is followed primarily': ['in'],
#  'followed primarily in': ['the'],
#  'primarily in the': ['Indian'],
#  'in the Indian': ['subcontinent'],
#  'the Indian subcontinent': [','],
#  'Indian subcontinent ,': ['Australasia'],
#  'subcontinent , Australasia': [','],
#  ', Australasia ,': ['the'],
#  'Australasia , the': ['United'],
#  ', the United': ['Kingdom'],
#  'the United Kingdom': [','],
#  'United Kingdom ,': ['Ireland'],
#  'Kingdom , Ireland': [','],
#  ', Ireland ,': ['southern'],
#  'Ireland , southern': ['Africa'],
#  ', southern Africa': ['and'],
#  'southern Africa and': ['the'],
#  'Africa and the': ['West'],
#  'and the West': ['Indies'],
#  'the West Indies': [','],
#  'West Indies ,': ['its'],
#  'Indies , its': ['globalisation'],
#  ', its globalisation': ['occurring'],
#  'its globalisation occurring': ['during'],
#  'globalisation occurring during': ['the'],
#  'occurring during the': ['expansion'],
#  'during the expansion': ['of'],
#  'British Empire and': ['remaining'],
#  'Empire and remaining': ['popular'],
#  'and remaining popular': ['into'],
#  'remaining popular into': ['the'],
#  'popular into the': ['21st'],
#  'into the 21st': ['century'],
#  'the 21st century': ['.'],
#  '21st century .': ['['],
#  'century . [': ['1'],
#  '. [ 1': [']'],
#  '[ 1 ]': ['Women'],
#  '1 ] Women': ["'s"],
#  "] Women 's": ['cricket'],
#  "Women 's cricket": [','],
#  "'s cricket ,": ['which'],
#  'cricket , which': ['is'],
#  'which is organised': ['and'],
#  'is organised and': ['played'],
#  'organised and played': ['separately'],
#  'and played separately': [','],
#  'played separately ,': ['has'],
#  'separately , has': ['also'],
#  ', has also': ['achieved'],
#  'has also achieved': ['international'],
#  'also achieved international': ['standard'],
#  'achieved international standard': ['.'],
#  'international standard .': ['The'],
#  'standard . The': ['most'],
#  '. The most': ['successful'],
#  'The most successful': ['side'],
#  'most successful side': ['playing'],
#  'successful side playing': ['international'],
#  'side playing international': ['cricket'],
#  'playing international cricket': ['is'],
#  'international cricket is': ['Australia'],
#  'cricket is Australia': [','],
#  'is Australia ,': ['having'],
#  'Australia , having': ['won'],
#  ', having won': ['seven'],
#  'having won seven': ['One'],
#  'won seven One': ['Day'],
#  'seven One Day': ['International'],
#  'One Day International': ['trophies'],
#  'Day International trophies': [','],
#  'International trophies ,': ['including'],
#  'trophies , including': ['five'],
#  ', including five': ['World'],
#  'including five World': ['Cups'],
#  'five World Cups': [','],
#  'World Cups ,': ['more'],
#  'Cups , more': ['than'],
#  ', more than': ['any'],
#  'more than any': ['other', 'other'],
#  'than any other': ['country', 'country'],
#  'any other country': [',', '.'],
#  'other country ,': ['and'],
#  'country , and': ['having'],
#  ', and having': ['been'],
#  'and having been': ['the'],
#  'having been the': ['top-rated'],
#  'been the top-rated': ['Test'],
#  'the top-rated Test': ['side'],
#  'top-rated Test side': ['more'],
#  'Test side more': ['than'],
#  'side more than': ['any'],
#  'Cri': ['c', 'c', 'c', 'c'],
#  'ric': ['k', 'k', 'k', 'a', 'k', 'k', 'k', 'k', 'a', 'k', 'k'],
#  'ick': ['e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e'],
#  'cke': ['t', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't'],
#  'ket': [' ', ' ', ' ', 'e', ' ', "'", ' ', ' ', ' ', ',', ' '],
#  'et ': ['i', 'a', 'w', 't', 'C', 'w', 'C', 'i'],
#  't i': ['s', 's', 'n', 'n', 'n', 's', 's'],
#  ' is': [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  'is ': ['a', 'a', 'a', 'h', 'a', 'a', 'l', 'i', 't', 'o', 'f', 'o', 'A'],
#  's a': [' ', ' ', 'n', 'n', 'n', 'd', 'n', ' ', 'r', 'r', 'l'],
#  ' a ': ['b', 'f', '2', 'w', 't', 'f', 's', 'h', 's', 'c', 'c'],
#  'a b': ['a'],
#  ' ba': ['t', 'i', 'l', 't', 'l', 't', 'l', 'i', 'l', 't', 't', 't', 's', 'l'],
#  'bat': ['-', 't', ',', ',', 't', 't'],
#  'at-': ['a'],
#  't-a': ['n'],
#  '-an': ['d'],
#  'and': ['-',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ',',
#   ' ',
#   ' ',
#   ' ',
#   'a',
#   ' '],
#  'nd-': ['b'],
#  'd-b': ['a'],
#  '-ba': ['l'],
#  'bal': ['l', 'a', 'l', 'l', 'l', 'l', 'l', 'i'],
#  'all': [' ', ' ', ' ', ' ', 'y', '-', ',', 'y', 'y', 'e'],
#  'll ': ['g', 'b', 'h', 'a', 'm'],
#  'l g': ['a'],
#  ' ga': ['m', 'm', 'm', 'm'],
#  'gam': ['e', 'e', 'e', 'e'],
#  'ame': [' ', ' ', "'", "'"],
#  'me ': ['p', 'i', 'p'],
#  'e p': ['l', 'l', 'l'],
#  ' pl': ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'],
#  'pla': ['y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y'],
#  'lay': ['e', 'e', 'e', 'e', 'e', 'e', ' ', 'e', 'e', ' ', 'e', 'i'],
#  'aye': ['d', 'r', 'r', 'r', 'd', 'd', 'r', 'r', 'd'],
#  'yed': [' ', ' ', ' ', ' '],
#  'ed ': ['b',
#   'o',
#   'a',
#   'b',
#   'b',
#   'o',
#   'o',
#   'o',
#   'l',
#   'o',
#   'b',
#   'l',
#   's',
#   'w',
#   't',
#   'a',
#   'b',
#   'p',
#   'K',
#   'a',
#   's',
#   'i',
#   'T'],
#  'd b': ['e', 'y', 'y', 'y', 'y', 'y'],
#  ' be': ['t', 'i', 'f', 'e', 'e'],
#  'bet': ['w'],
#  'etw': ['e'],
#  'twe': ['e', 'l'],
#  'wee': ['n'],
#  'een': [' ', ' ', ' '],
#  'en ': ['t', 'p', 't', 't', 'p', 'd', 'O', 't'],
#  'n t': ['w', 'h', 'h', 'e', 'o', 'h', 'h', 'h', 'h'],
#  ' tw': ['o', 'o', 'o', 'o', 'o', 'e'],
#  'two': [' ', ' ', ' ', ' ', ' '],
#  'wo ': ['t', 'b', 'u', 'o', 'i'],
#  'o t': ['e', 'h', 'h', 'h', 'h'],
#  ' te': ['a', 'n', 'a', 'a', 'a', 'a'],
#  'tea': ['m', 'm', 'm', 'm', 'm'],
#  'eam': ['s', 's', ' ', 's', ' ', ' '],
#  'ams': [' ', ' ', ' '],
#  'ms ': ['o', 's', 'e'],
#  's o': ['f', 'n', 'f', 'f', 'f', 'r', 'v', 'f', 'w', 'r'],
#  ' of': [' ', ' ', ' ', 'f', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  'of ': ['e', 'w', 'd', '2', 'u', 'c', 't', 't', 't', 'w', 'C', 't'],
#  'f e': ['l'],
#  ' el': ['e'],
#  'ele': ['v'],
#  'lev': ['e'],
#  'eve': ['n', 'n', 'n', 'd', 'n'],
#  'ven': [' ', 't', 't', ' '],
#  'n p': ['l', 'l'],
#  'yer': ['s', ' ', 's', 's', 'e'],
#  'ers': [' ', ' ', ' ', ',', ' ', ' ', ' ', ' ', ',', ' '],
#  'rs ': ['o', 'h', 'w', 'w', 'a', 'p', 'c', 'w', 'w'],
#  ' on': [' ', ' '],
#  'on ': ['a', 't', 't', 'o', 'o', 'o', 's'],
#  'n a': [' ', 'l', 'd', 'n', ' ', 'n', 'n'],
#  'a f': ['i', 'e'],
#  ' fi': ['e', 'e', 'e', 'v', 'r', 'v'],
#  'fie': ['l', 'l', 'l', 'l'],
#  'iel': ['d', 'd', 'd', 'd'],
#  'eld': [' ', 'i', 'i', ' ', ' '],
#  'ld ': ['a', 's', 'i', 'C'],
#  'd a': ['t', 't', 'n', 'n'],
#  ' at': [' ', ' ', ' '],
#  'at ': ['t', 'e', 't'],
#  't t': ['h', 'h', 'h', 'h'],
#  ' th': ['e',
#   'r',
#   'e',
#   'e',
#   'e',
#   'e',
#   'i',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'i',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'e',
#   'a',
#   'e',
#   'a'],
#  'the': [' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   'y',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   'y',
#   ' ',
#   ' ',
#   'r',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   'r',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   'r',
#   ' ',
#   'r'],
#  'he ': ['c',
#   'b',
#   'b',
#   'w',
#   'b',
#   'b',
#   'b',
#   's',
#   'b',
#   'f',
#   'b',
#   'b',
#   'g',
#   'i',
#   't',
#   'g',
#   'm',
#   't',
#   'b',
#   'b',
#   'e',
#   'm',
#   '1',
#   'e',
#   'B',
#   'f',
#   's',
#   '1',
#   'g',
#   'I',
#   'g',
#   'L',
#   's',
#   'I',
#   'U',
#   'W',
#   'e',
#   'B',
#   '2',
#   'm',
#   't'],
#  'e c': ['e', 'a', 'a'],
#  ' ce': ['n', 'n', 'n', 'n'],
#  'cen': ['t', 't', 't', 't'],
#  'ent': ['r', ' ', 'y', ' ', 'u', 'u', ',', 'u'],
#  'ntr': ['e', 'y', 'y'],
#  'tre': [' ', ' '],
#  're ': ['o', '(', '"', 'i', 'a', 'a', 'v', 'w', 'u', 'f', 'h', 'a', 't', 't'],
#  'e o': ['f', 'f', 'f', 'f'],
#  'f w': ['h', 'h'],
#  ' wh': ['i', 'i', 'e', 'o', 'i', 'i', 'i', 'i', 'o', 'i', 'i'],
#  'whi': ['c', 'l', 't', 'c', 'c', 'c', 'c', 'c', 'c'],
#  'hic': ['h', 'h', 'h', 'h', 'h', 'h', 'h'],
#  'ich': [' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  'ch ': ['i', 'w', 'e', 'c', 'p', 'r', 't', 'b', 'i', 'i', 'h', 'a', 'i', 'i'],
#  'h i': ['s', 's', 's', 's', 's'],
#  'a 2': ['0'],
#  ' 20': ['-', ' '],
#  '20-': ['m'],
#  '0-m': ['e'],
#  '-me': ['t'],
#  'met': ['r'],
#  'etr': ['e'],
#  'e (': ['2'],
#  ' (2': ['2'],
#  '(22': ['-'],
#  '22-': ['y'],
#  '2-y': ['a'],
#  '-ya': ['r'],
#  'yar': ['d'],
#  'ard': [')', ',', '.'],
#  'rd)': [' '],
#  'd) ': ['p'],
#  ') p': ['i'],
#  ' pi': ['t'],
#  'pit': ['c'],
#  'itc': ['h'],
#  'tch': [' ', 'i', ' ', 'e', "'", 'e', 'e', 'e'],
#  'h w': ['i'],
#  ' wi': ['t', 'c', 'c', 't', 't', 't', 't', 't', 't', 't'],
#  'wit': ['h', 'h', 'h', 'h', 'h', 'h', 'h', 'h'],
#  'ith': [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  'th ': ['a', 't', 't', 'e', 'u', 'a', 't', 'c', 't', 'c'],
#  'h a': [' ', ' ', 'r'],
#  'a w': ['i'],
#  'wic': ['k', 'k'],
#  't a': ['t'],
#  't e': ['a'],
#  ' ea': ['c', 'c', 'c', 'c', 'c', 'r'],
#  'eac': ['h', 'h', 'h', 'h', 'h'],
#  'ach': [' ', ' ', ' ', ' ', ' ', 'i'],
#  'h e': ['n', 'a'],
#  ' en': ['d', 'd', 'c'],
#  'end': [',', 's'],
#  'nd,': [' ', ' '],
#  'd, ': ['e', 'w', 't', 's', 's'],
#  ', e': ['a'],
#  'h c': ['o', 'e', 'e'],
#  ' co': ['m', 'm', 'l', 'm', 'r', 'r', 'd', 'u', 'u'],
#  'com': ['p', 'm', 'p'],
#  'omp': ['r', 'r'],
#  'mpr': ['i', 'e'],
#  'pri': ['s', 'm'],
#  'ris': ['i'],
#  'isi': ['n'],
#  'sin': ['g', 'g', 'g'],
#  'ing': [' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   's',
#   ' ',
#   ' ',
#   'l',
#   's',
#   ' ',
#   's',
#   ' ',
#   '.',
#   ' ',
#   ' ',
#   'd',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' '],
#  'ng ': ['t',
#   's',
#   't',
#   'a',
#   's',
#   'b',
#   's',
#   't',
#   'f',
#   'f',
#   'f',
#   'a',
#   't',
#   'b',
#   'd',
#   't',
#   'p',
#   'i',
#   'w',
#   'f',
#   'b'],
#  'g t': ['w', 'h', 'h', 'o', 'h'],
#  'o b': ['a'],
#  'bai': ['l', 'l'],
#  'ail': ['s', 's'],
#  'ils': [' ', ','],
#  'ls ': ['b'],
#  's b': ['a', 'y'],
#  'ala': ['n', 's'],
#  'lan': ['c', 'd', 'd'],
#  'anc': ['e'],
#  'nce': ['d', 'r', ' '],
#  'ced': [' '],
#  'd o': ['n', 'v', 'v', 'v', 'v'],
#  'thr': ['e'],
#  'hre': ['e'],
#  'ree': [' ', ' '],
#  'ee ': ['s', 'i'],
#  'e s': ['t', 'c', 't', 'e', 'p'],
#  ' st': ['u', 'r', 'u', 'a', 'r', 'a'],
#  'stu': ['m', 'm'],
#  'tum': ['p', 'p'],
#  'ump': ['s', 's', 'i', 'i'],
#  'mps': ['.', ' '],
#  'ps.': [' '],
#  's. ': ['T', 'T', 'T', 'I', 'T'],
#  '. T': ['h', 'h', 'h', 'r', 'h', 'h', 'h', 'h'],
#  ' Th': ['e', 'e', 'e', 'e', 'e', 'e', 'e'],
#  'The': [' ', ' ', 'y', 'r', ' ', ' ', ' ', ' '],
#  'e b': ['a', 'a', 'a', 'o', 'e', 'a', 'a', 'a', 'a', 'e', 'a', 'a'],
#  'att': ['i', 'i', 'i'],
#  'tti': ['n', 'n', 'n'],
#  'tin': ['g', 'g', 'g', 'e'],
#  'g s': ['i', 'i', 'i'],
#  ' si': ['d', 'd', 'd', 'n', 'd', 'd'],
#  'sid': ['e', 'e', 'e', 'e', 'e'],
#  'ide': [' ', ' ', ' ', 'd', ' ', ' '],
#  'de ': ['s', 't', 'b', 'c', 'o', 'c', 'p', 'm'],
#  ' sc': ['o', 'o'],
#  'sco': ['r', 'r'],
#  'cor': ['e', 'e', 'd', 'k', 'e'],
#  'ore': ['s', ' ', 'r', ' ', ' ', ' '],
#  'res': [' ', ',', 's'],
#  'es ': ['r', 't', 't', 'i', 'a'],
#  's r': ['u', 'a', 'u'],
#  ' ru': ['n', 'l'],
#  'run': ['s'],
#  'uns': [' '],
#  'ns ': ['b', 'o', 'a'],
#  ' by': [' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  'by ': ['s', 't', 't', 't', 'a', 't', 'M'],
#  'y s': ['t'],
#  'str': ['i', 'i', 'a', 'a'],
#  'tri': ['k', 'e', 'n'],
#  'rik': ['i'],
#  'iki': ['n'],
#  'kin': ['g'],
#  'l b': ['o'],
#  ' bo': ['w', 'w', 'w', 'd'],
#  'bow': ['l', 'l', 'l'],
#  'owl': ['e', 'i', 'e'],
#  'wle': ['d', 'd'],
#  'led': [' ', ',', ' '],
#  'e w': ['i', 'i', 'h'],
#  't w': ['i', 'h'],
#  'h t': ['h', 'w', 'e', 'i', 'h'],
#  'at,': [' ', ' '],
#  't, ': ['w', 'b', 'b', 's', 'A', 'w'],
#  ', w': ['h', 'h', 'h', 'h', 'h'],
#  'hil': ['e'],
#  'ile': [' '],
#  'le ': ['t', 'i', 'o'],
#  'e t': ['h', 'r', 'e', 'e', 'h', 'o', 'h'],
#  'wli': ['n'],
#  'lin': ['g'],
#  'g a': ['n', ' '],
#  ' an': ['d',
#   'd',
#   'd',
#   'd',
#   'd',
#   'd',
#   'd',
#   'd',
#   'd',
#   'd',
#   'd',
#   'd',
#   'y',
#   'd',
#   'y'],
#  'nd ': ['f',
#   'd',
#   'd',
#   'b',
#   't',
#   'm',
#   't',
#   's',
#   't',
#   'i',
#   'h',
#   'm',
#   't',
#   'r',
#   'p',
#   'h'],
#  'd f': ['i'],
#  'ldi': ['n', 'n'],
#  'din': ['g', 'g', 'g', 'g'],
#  ' tr': ['i', 'o'],
#  'rie': ['s'],
#  'ies': [' ', 't', ',', ','],
#  's t': ['o', 'h', 'h', 'h', 'h'],
#  ' to': [' ', ' ', ' ', ' ', ' ', 'p'],
#  'to ': ['p', 'T', 't', 'p', 't', 't'],
#  'o p': ['r', 'r', 'l'],
#  ' pr': ['e', 'o', 'e', 'i'],
#  'pre': ['v', 'v', 's', 'a'],
#  'rev': ['e', 'e'],
#  'nt ': ['t', 'i'],
#  'thi': ['s', 'r'],
#  'his': [' '],
#  'd d': ['i', 'i'],
#  ' di': ['s', 's', 's', 's'],
#  'dis': ['m', 'm', 'l', 'm'],
#  'ism': ['i', 'i', 'i'],
#  'smi': ['s', 's', 's'],
#  'mis': ['s', 's', 's'],
#  'iss': [' ', 'a', 'e'],
#  'ss ': ['e'],
#  's e': ['a', 'n', 'a'],
#  'h p': ['l'],
#  'er ': ['(', 'i', 'a', 'f', 'w', '1', 'c', 'c'],
#  'r (': ['s'],
#  ' (s': ['o'],
#  '(so': [' '],
#  'so ': ['t', 'a'],
#  'hey': [' ', ' ', ' '],
#  'ey ': ['a', 'c', 'w'],
#  'y a': ['r', ' '],
#  ' ar': ['e', 'e', 'e', 'e', 'e'],
#  'are': [' ', ' ', ' ', ' ', ' '],
#  'e "': ['o'],
#  ' "o': ['u'],
#  '"ou': ['t'],
#  'out': ['"', 'h', 'h'],
#  'ut"': [')'],
#  't")': ['.'],
#  '").': [' '],
#  '). ': ['M'],
#  '. M': ['e'],
#  ' Me': ['a'],
#  'Mea': ['n'],
#  'ean': ['s'],
#  'ans': [' ', 'i', 'i'],
#  'f d': ['i'],
#  'ssa': ['l'],
#  'sal': [' '],
#  'al ': ['i', 'm', 'i', 'm', 'C', 's', 'c', 't'],
#  'l i': ['n', 'n'],
#  ' in': ['c',
#   'n',
#   ' ',
#   't',
#   'f',
#   'n',
#   'n',
#   ' ',
#   ' ',
#   'j',
#   ' ',
#   ' ',
#   't',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   't',
#   't',
#   't',
#   'c'],
#  'inc': ['l', 'l'],
#  'ncl': ['u', 'o', 'u'],
#  'clu': ['d', 'b', 'd'],
#  'lud': ['e', 'i'],
#  'ude': [' '],
#  'bei': ['n'],
#  'ein': ['g'],
#  'g b': ['o', 'o', 'e'],
#  'ed,': [' ', ' '],
#  'whe': ['n'],
#  'hen': [' ', ' '],
#  'l h': ['i'],
#  ' hi': ['t', 't', 't'],
#  'hit': ['s', ' ', 's', 'e'],
#  'its': [' ', ' ', ' '],
#  'ts ': ['t', 't', 'r', 'g'],
#  'ps ': ['a'],
#  'isl': ['o'],
#  'slo': ['d'],
#  'lod': ['g'],
#  'odg': ['e'],
#  'dge': ['s'],
#  'ges': [' '],
#  'ls,': [' '],
#  's, ': ['a', 'a', 't', 'p', 't', 'i', 'i', 'm'],
#  ', a': ['n', 'i', 'n'],
#  'y t': ['h', 'h', 'w', 'h'],
#  'e f': ['i', 'i', 'u'],
#  ' ca': ['t', 'u', 'l'],
#  'cat': ['c', 'e', 'e'],
#  'atc': ['h', 'h', 'h', 'h', 'h', 'h', 'h'],
#  'chi': ['n', 'e'],
#  'hin': ['g'],
#  'l a': ['f'],
#  ' af': ['t'],
#  'aft': ['e'],
#  'fte': ['r'],
#  'ter': [' ', 'n', 's', 'n', 'n', 'n', 'n', 'n'],
#  'r i': ['t', 'n'],
#  ' it': [' ', ' ', 's'],
#  'it ': ['i', 'b', 'h'],
#  's h': ['i', 'a'],
#  't b': ['y', 'e'],
#  ', b': ['u', 'u'],
#  ' bu': ['t', 't'],
#  'but': [' ', ' '],
#  'ut ': ['b', 'i'],
#  'bef': ['o'],
#  'efo': ['r'],
#  'for': ['e', 'm', 'm', ' ', ' '],
#  'e i': ['t', 'n', 's', 'n', 'n', 's'],
#  't h': ['i'],
#  'e g': ['r', 'a', 'e', 'a', 'a'],
#  ' gr': ['o'],
#  'gro': ['u'],
#  'rou': ['n'],
#  'oun': ['d', 'd', 'c', 't', 't'],
#  'und': ['.', ' '],
#  'nd.': [' '],
#  'd. ': ['W', 'T'],
#  '. W': ['h'],
#  ' Wh': ['e'],
#  'Whe': ['n'],
#  'ten': [' '],
#  ' ha': ['v', 'r', 'l', 's', 's', 'v', 'v'],
#  'hav': ['e', 'i', 'i'],
#  'ave': [' '],
#  've ': ['b', 'd', 'g', 'o', 'W'],
#  'bee': ['n', 'n'],
#  'n d': ['i'],
#  'sse': ['d', 'd'],
#  'sed': [',', ' ', ' ', ' ', ' '],
#  ', t': ['h', 'o', 'w', 'h'],
#  'inn': ['i', 'i', 'i'],
#  'nni': ['n', 'n', 'n'],
#  'nin': ['g', 'g', 'g', 'g', 'g'],
#  'ngs': [' ', ' ', ' '],
#  'gs ': ['e', 'o', 'o'],
#  'nds': [' '],
#  'ds ': ['a'],
#  'd t': ['h', 'h', 'h', 'h', 'h', 'h'],
#  's s': ['w', 't'],
#  ' sw': ['a'],
#  'swa': ['p'],
#  'wap': [' '],
#  'ap ': ['r'],
#  'p r': ['o'],
#  ' ro': ['l'],
#  'rol': ['e'],
#  'ole': ['s'],
#  'les': ['.', ' '],
#  'es.': [' ', ' ', ' '],
#  ' ad': ['j', 'd'],
#  'adj': ['u'],
#  'dju': ['d'],
#  'jud': ['i'],
#  'udi': ['c', 'n'],
#  'dic': ['a'],
#  'ica': ['t', 't', 'l', 'l', ' '],
#  'ate': ['d', ' ', 'l', 'd'],
#  'ted': [' ', ' ', ' ', ' ', ' ', ' '],
#  'o u': ['m'],
#  ' um': ['p', 'p'],
#  'mpi': ['r', 'r', 'r', 'r'],
#  'pir': ['e', 'e', 'e', 'e'],
#  'ire': ['s', ' ', ',', ' '],
#  'es,': [' ', ' ', ' ', ' '],
#  ' ai': ['d'],
#  'aid': ['e'],
#  'ded': [' '],
#  'a t': ['h'],
#  'hir': ['d'],
#  'ird': [' '],
#  'rd ': ['u', 't'],
#  'd u': ['m'],
#  'e a': ['n', 'r', 'n'],
#  'd m': ['a', 'a', 'a'],
#  ' ma': ['t', 't', 't', 't', 'd', 't', 't', 'i'],
#  'mat': ['c', 'c', 'c', 'i', 's', 'c', 'c', 'c'],
#  'h r': ['e'],
#  ' re': ['f', 'c', 'f', 'm'],
#  'ref': ['e', 'e'],
#  'efe': ['r', 'r'],
#  'fer': ['e', 'e'],
#  'ere': ['e', ' ', 'd', 'n'],
#  'in ': ['i', 'a', 'l', 'a', 's', 't', 't', 'a', 'L', 't'],
#  'n i': ['n'],
#  'int': ['e', 'e', 'a', 'o', 'e', 'e'],
#  'nte': ['r', 'r', 'r', 'r', 'r', 'r'],
#  'ern': ['a', 'a', 'i', 'a', ' ', 'a', 'a', 'a'],
#  'rna': ['t', 't', 't', 't', 't', 't'],
#  'nat': ['i', 'i', 'i', 'i', 'i', 'i'],
#  'ati': ['o', 's', 'o', 'o', 'o', 'o', 'o', 'o', 'o'],
#  'tio': ['n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n'],
#  'ion': ['a', '.', 'a', ' ', ' ', 'a', 'a', ' ', ' ', 'a', 'a', 'a'],
#  'ona': ['l', 'l', 'l', 'l', 'l', 'l', 'l'],
#  'nal': [' ', 'l', ' ', ' ', ' ', ' ', ' '],
#  'l m': ['a', 'a', 'e'],
#  'che': ['s', 's', 's', 's'],
#  'hes': ['.', ',', ' ', '.'],
#  'y c': ['o', 'r', 'a'],
#  'omm': ['u'],
#  'mmu': ['n'],
#  'mun': ['i'],
#  'uni': ['c'],
#  'nic': ['a'],
#  'te ': ['w', 'k', 'r'],
#  'o o': ['f'],
#  'off': ['-'],
#  'ff-': ['f'],
#  'f-f': ['i'],
#  '-fi': ['e'],
#  'd s': ['c', 'p', 'e', 't', 'e'],
#  'rer': ['s'],
#  's w': ['h', 'i', 'i', 'e', 'h'],
#  'who': [' ', ' '],
#  'ho ': ['r', 'p'],
#  'o r': ['e'],
#  'rec': ['o'],
#  'eco': ['r', 'n'],
#  'ord': [' '],
#  'e m': ['a', 'i', 'o', 'o'],
#  "ch'": ['s'],
#  "h's": [' '],
#  "'s ": ['s', 'o', 'g', 'r', 'c'],
#  'sta': ['t', 'n'],
#  'tat': ['i'],
#  'tis': ['t', 'h', 'h'],
#  'ist': ['i', 'o'],
#  'sti': ['c'],
#  'tic': ['a'],
#  'cal': [' ', 'l', 'l'],
#  'inf': ['o'],
#  'nfo': ['r'],
#  'orm': ['a', 'a'],
#  'rma': ['t', 't'],
#  'on.': ['\n', ' '],
#  'n.\n': ['\n'],
#  '.\n\n': ['T', 'H'],
#  '\n\nT': ['h'],
#  '\nTh': ['e'],
#  'her': ['e', 'o', ' ', 'n', ' ', ' '],
#  'e v': ['a'],
#  ' va': ['r'],
#  'var': ['i'],
#  'ari': ['o', 'l'],
#  'rio': ['u'],
#  'iou': ['s'],
#  'ous': [' '],
#  'us ': ['f'],
#  's f': ['o', 'o'],
#  ' fo': ['r', 'r', 'r', 'l'],
#  'ats': [' '],
#  ' ra': ['n', 'i'],
#  'ran': ['g'],
#  'ang': ['i'],
#  'ngi': ['n'],
#  'gin': ['g', 's'],
#  'g f': ['r', 'o', 'o', 'i'],
#  ' fr': ['o'],
#  'fro': ['m'],
#  'rom': [' '],
#  'om ': ['T'],
#  'm T': ['w'],
#  ' Tw': ['e'],
#  'Twe': ['n'],
#  'wen': ['t'],
#  'nty': ['2'],
#  'ty2': ['0'],
#  'y20': [','],
#  '20,': [' '],
#  '0, ': ['p'],
#  ', p': ['l', 'l'],
#  ' ov': ['e', 'e', 'e', 'e', 'e', 'e'],
#  'ove': ['r', 'r', 'r', 'r', 'r', 'r', 'r'],
#  'ver': [' ', 's', ' ', 's', 's', 'n', ' '],
#  'r a': [' ', ' '],
#  ' fe': ['w'],
#  'few': [' '],
#  'ew ': ['h'],
#  'w h': ['o'],
#  ' ho': ['u'],
#  'hou': ['r'],
#  'our': ['s', 's'],
#  'urs': [' ', '.'],
#  'am ': ['b', 'c', 'e'],
#  'm b': ['a'],
#  'or ': ['a', 't', 't'],
#  'a s': ['i', 'l'],
#  'ngl': ['e', 'a'],
#  'gle': [' '],
#  ...}

# %%
#testing the n gram model
currentGram = text[0:n]
result = currentGram
for i in range(100):
    if currentGram not in ngrams.keys():
        break
    possibilities = ngrams[currentGram]
    nextItem =possibilities[random.randrange(len(possibilities))]
    result += nextItem
    currentGram = result[len(result)-n : len(result)]

# %%
print (result)
# Out:
# Cricket, but in and, sout"). Meansional international cricate refere its the in team batting third the

# %%
#n gram words models

# %%
words = nltk.word_tokenize(text)
for i in range(len(words)-n):
    gram = ' '.join(words[i:i+n])
    if gram not in ngrams.keys():
        ngrams[gram]=[]
    ngrams[gram].append(words[i+n])

# %%
print (ngrams)
# Out:
# {'Cricket is a': ['bat-and-ball'], 'is a bat-and-ball': ['game'], 'a bat-and-ball game': ['played'], 'bat-and-ball game played': ['between'], 'game played between': ['two'], 'played between two': ['teams'], 'between two teams': ['of'], 'two teams of': ['eleven'], 'teams of eleven': ['players'], 'of eleven players': ['on'], 'eleven players on': ['a'], 'players on a': ['field'], 'on a field': ['at'], 'a field at': ['the'], 'field at the': ['centre'], 'at the centre': ['of'], 'the centre of': ['which'], 'centre of which': ['is'], 'of which is': ['a'], 'which is a': ['20-metre', 'hard'], 'is a 20-metre': ['('], 'a 20-metre (': ['22-yard'], '20-metre ( 22-yard': [')'], '( 22-yard )': ['pitch'], '22-yard ) pitch': ['with'], ') pitch with': ['a'], 'pitch with a': ['wicket'], 'with a wicket': ['at'], 'a wicket at': ['each'], 'wicket at each': ['end'], 'at each end': [','], 'each end ,': ['each'], 'end , each': ['comprising'], ', each comprising': ['two'], 'each comprising two': ['bails'], 'comprising two bails': ['balanced'], 'two bails balanced': ['on'], 'bails balanced on': ['three'], 'balanced on three': ['stumps'], 'on three stumps': ['.'], 'three stumps .': ['The'], 'stumps . The': ['batting'], '. The batting': ['side'], 'The batting side': ['scores'], 'batting side scores': ['runs'], 'side scores runs': ['by'], 'scores runs by': ['striking'], 'runs by striking': ['the'], 'by striking the': ['ball'], 'striking the ball': ['bowled'], 'the ball bowled': ['at'], 'ball bowled at': ['the'], 'bowled at the': ['wicket'], 'at the wicket': ['with'], 'the wicket with': ['the'], 'wicket with the': ['bat'], 'with the bat': [','], 'the bat ,': ['while', 'but'], 'bat , while': ['the'], ', while the': ['bowling'], 'while the bowling': ['and'], 'the bowling and': ['fielding'], 'bowling and fielding': ['side'], 'and fielding side': ['tries'], 'fielding side tries': ['to'], 'side tries to': ['prevent'], 'tries to prevent': ['this'], 'to prevent this': ['and'], 'prevent this and': ['dismiss'], 'this and dismiss': ['each'], 'and dismiss each': ['player'], 'dismiss each player': ['('], 'each player (': ['so'], 'player ( so': ['they'], '( so they': ['are'], 'so they are': ['``'], 'they are ``': ['out'], 'are `` out': ["''"], "`` out ''": [')'], "out '' )": ['.'], "'' ) .": ['Means'], ') . Means': ['of'], '. Means of': ['dismissal'], 'Means of dismissal': ['include'], 'of dismissal include': ['being'], 'dismissal include being': ['bowled'], 'include being bowled': [','], 'being bowled ,': ['when'], 'bowled , when': ['the'], ', when the': ['ball'], 'when the ball': ['hits'], 'the ball hits': ['the'], 'ball hits the': ['stumps'], 'hits the stumps': ['and'], 'the stumps and': ['dislodges'], 'stumps and dislodges': ['the'], 'and dislodges the': ['bails'], 'dislodges the bails': [','], 'the bails ,': ['and'], 'bails , and': ['by'], ', and by': ['the'], 'and by the': ['fielding'], 'by the fielding': ['side'], 'the fielding side': ['catching'], 'fielding side catching': ['the'], 'side catching the': ['ball'], 'catching the ball': ['after'], 'the ball after': ['it'], 'ball after it': ['is'], 'after it is': ['hit'], 'it is hit': ['by'], 'is hit by': ['the'], 'hit by the': ['bat'], 'by the bat': [','], 'bat , but': ['before'], ', but before': ['it'], 'but before it': ['hits'], 'before it hits': ['the'], 'it hits the': ['ground'], 'hits the ground': ['.'], 'the ground .': ['When'], 'ground . When': ['ten'], '. When ten': ['players'], 'When ten players': ['have'], 'ten players have': ['been'], 'players have been': ['dismissed'], 'have been dismissed': [','], 'been dismissed ,': ['the'], 'dismissed , the': ['innings'], ', the innings': ['ends'], 'the innings ends': ['and'], 'innings ends and': ['the'], 'ends and the': ['teams'], 'and the teams': ['swap', 'each'], 'the teams swap': ['roles'], 'teams swap roles': ['.'], 'swap roles .': ['The'], 'roles . The': ['game'], '. The game': ['is', "'s", "'s"], 'The game is': ['adjudicated'], 'game is adjudicated': ['by'], 'i ...

# %%
currentGram = ' '.join(words[0:n])
reuslt = currentGram
for i in range(20):
    if currentGram not in ngrams.keys():
        break
    possibilities = ngrams[currentGram]
    nextItem = possibilities[random.randrange(len(possibilities))]
    result += ' '+nextItem
    rwords = nltk.word_tokenize(result)
    currentGram = ' '.join(rwords[len(rwords)-n:len(rwords)])

# %%
print (result)
# Out:
# Cricket, but in and, sout"). Meansional international cricate refere its the in team batting third the  bat-and-ball bat-and-ball bat-and-ball
